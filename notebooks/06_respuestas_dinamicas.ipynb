# %%
import pandas as pd

# %%
# CARGAR FEATURES
features = pd.read_csv(
    "../data/processed/features.csv"
)

# %%
# SIMULACION
user_id = "USR-00001"

# %%
usuario = features[
    features["user_id"] == user_id
]

# %%
# Extraer datos 
gasto_total = usuario["gasto_total"].values[0]

cashback = usuario["cashback_total"].values[0]

categoria = usuario["categoria_favorita"].values[0]

cluster = usuario["cluster"].values[0]

# %%
# Generar respuesta
